# %%
import pandas as pd
import numpy as np
data=pd.read_csv("washington-history.csv")
data.head()
# Out:
#          date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    WA  5041.0             NaN              0            NaN
# 1  2021-03-06    WA  5041.0             NaN              9            NaN
# 2  2021-03-05    WA  5032.0             NaN             20            NaN
# 3  2021-03-04    WA  5012.0             NaN             24            NaN
# 4  2021-03-03    WA  4988.0             NaN             19            NaN
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0       19599.0                 19599.0                  431.0
# 1       19556.0                 19556.0                  431.0
# 2       19500.0                 19500.0                  413.0
# 3       19466.0                 19466.0                  461.0
# 4       19433.0                 19433.0                  467.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
data.tail()
# Out:
#            date state  death  deathConfirmed  deathIncrease  deathProbable  \
# 415  2020-01-17    WA    NaN             NaN              0            NaN
# 416  2020-01-16    WA    NaN             NaN              0            NaN
# 417  2020-01-15    WA    NaN             NaN              0            NaN
# 418  2020-01-14    WA    NaN             NaN              0            NaN
# 419  2020-01-13    WA    NaN             NaN              0            NaN
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 415           NaN                     NaN                    NaN
# 416           NaN                     NaN                    NaN
# 417           NaN                     NaN                    NaN
# 418           NaN                     NaN                    NaN
# 419           NaN                     NaN                    NaN
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
data.shape
# Out:
# (420, 41)

# %%
data.columns
# Out:
# Index(['date', 'state', 'death', 'deathConfirmed', 'deathIncrease',
#        'deathProbable', 'hospitalized', 'hospitalizedCumulative',
#        'hospitalizedCurrently', 'hospitalizedIncrease', 'inIcuCumulative',
#        'inIcuCurrently', 'negative', 'negativeIncrease',
#        'negativeTestsAntibody', 'negativeTestsPeopleAntibody',
#        'negativeTestsViral', 'onVentilatorCumulative', 'onVentilatorCurrently',
#        'positive', 'positiveCasesViral', 'positiveIncrease', 'positiveScore',
#        'positiveTestsAntibody', 'positiveTestsAntigen',
#        'positiveTestsPeopleAntibody', 'positiveTestsPeopleAntigen',
#        'positiveTestsViral', 'recovered', 'totalTestEncountersViral',
#        'totalTestEncountersViralIncrease', 'totalTestResults',
#        'totalTestResultsIncrease', 'totalTestsAntibody', 'totalTestsAntigen',
#        'totalTestsPeopleAntibody', 'totalTestsPeopleAntigen',
#        'totalTestsPeopleViral', 'totalTestsPeopleViralIncrease',
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.loc[(data.deathIncrease==5)]
# Out:
#            date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 172  2020-09-16    WA  2020.0          2020.0              5            NaN
# 213  2020-08-06    WA  1624.0          1624.0              5            NaN
# 235  2020-07-15    WA  1404.0          1404.0              5            NaN
# 244  2020-07-06    WA  1359.0          1359.0              5            NaN
# 258  2020-06-22    WA  1270.0          1270.0              5            NaN
# 277  2020-06-03    WA  1129.0          1129.0              5            NaN
# 281  2020-05-30    WA  1111.0          1111.0              5            NaN
# 287  2020-05-24    WA  1055.0          1055.0              5            NaN
# 317  2020-04-24    WA   659.0             NaN              5            NaN
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 172        7162.0                  7162.0                  357.0
# 213        5840.0                  5840.0                  518.0
# ...

# %%
data.notnull().sum()
# Out:
# date                                420
# state                               420
# death                               376
# deathConfirmed                      227
# deathIncrease                       420
# deathProbable                         0
# hospitalized                        291
# hospitalizedCumulative              291
# hospitalizedCurrently               338
# hospitalizedIncrease                420
# inIcuCumulative                       0
# inIcuCurrently                      217
# negative                              0
# negativeIncrease                    420
# negativeTestsAntibody                 0
# negativeTestsPeopleAntibody           0
# negativeTestsViral                   28
# onVentilatorCumulative                0
# onVentilatorCurrently               291
# positive                            419
# positiveCasesViral                  419
# positiveIncrease                    420
# positiveScore                       420
# ...

# %%
data.loc[(data.deathIncrease==5)&(data.hospitalized>=4000)]
# Out:
#            date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 172  2020-09-16    WA  2020.0          2020.0              5            NaN
# 213  2020-08-06    WA  1624.0          1624.0              5            NaN
# 235  2020-07-15    WA  1404.0          1404.0              5            NaN
# 244  2020-07-06    WA  1359.0          1359.0              5            NaN
# 258  2020-06-22    WA  1270.0          1270.0              5            NaN
#
#      hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 172        7162.0                  7162.0                  357.0
# 213        5840.0                  5840.0                  518.0
# 235        4788.0                  4788.0                  497.0
# 244        4482.0                  4482.0                  398.0
# 258        4049.0                  4049.0                  362.0
#
#      hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
data.loc[(data.deathIncrease==5)|(data.hospitalized>=4000)]
# Out:
#            date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 0    2021-03-07    WA  5041.0             NaN              0            NaN
# 1    2021-03-06    WA  5041.0             NaN              9            NaN
# 2    2021-03-05    WA  5032.0             NaN             20            NaN
# 3    2021-03-04    WA  5012.0             NaN             24            NaN
# 4    2021-03-03    WA  4988.0             NaN             19            NaN
# ..          ...   ...     ...             ...            ...            ...
# 260  2020-06-20    WA  1255.0          1255.0             10            NaN
# 277  2020-06-03    WA  1129.0          1129.0              5            NaN
# 281  2020-05-30    WA  1111.0          1111.0              5            NaN
# 287  2020-05-24    WA  1055.0          1055.0              5            NaN
# 317  2020-04-24    WA   659.0             NaN              5            NaN
#
# ...

# %%
data["hospitalizedCurrently"].mean()
# Out:
# 609.1627218934912

# %%
data.replace(to_replace=np.nan,value=98 ,inplace=True)

# %%
data
# Out:
#            date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 0    2021-03-07    WA  5041.0            98.0              0           98.0
# 1    2021-03-06    WA  5041.0            98.0              9           98.0
# 2    2021-03-05    WA  5032.0            98.0             20           98.0
# 3    2021-03-04    WA  5012.0            98.0             24           98.0
# 4    2021-03-03    WA  4988.0            98.0             19           98.0
# ..          ...   ...     ...             ...            ...            ...
# 415  2020-01-17    WA    98.0            98.0              0           98.0
# 416  2020-01-16    WA    98.0            98.0              0           98.0
# 417  2020-01-15    WA    98.0            98.0              0           98.0
# 418  2020-01-14    WA    98.0            98.0              0           98.0
# 419  2020-01-13    WA    98.0            98.0              0           98.0
#
# ...

# %%
data=pd.read_csv("Pokemon.csv")

# data.replace(to_replace=np.nan,value=98 ,inplace=True)
data.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
data["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.sort_values("Generation",ascending=False)
# Out:
#        #       Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 799  721  Volcanion      Fire    Water    600   80     110      120      130
# 738  670    Floette     Fairy      NaN    371   54      45       47       75
# 740  672     Skiddo     Grass      NaN    350   66      65       48       62
# 741  673     Gogoat     Grass      NaN    531  123     100       62       97
# 742  674    Pancham  Fighting      NaN    348   67      82       62       46
# ..   ...        ...       ...      ...    ...  ...     ...      ...      ...
# 110  102  Exeggcute     Grass  Psychic    325   60      40       80       60
# 109  101  Electrode  Electric      NaN    480   60      50       70       80
# 108  100    Voltorb  Electric      NaN    330   40      30       50       55
# 107   99    Kingler     Water      NaN    475   55     130      115       50
# 0      1  Bulbasaur     Grass   Poison    318   45      49       49       65
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
data.sort_values(["Generation","Speed"],ascending=[1,0])
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 71    65      AlakazamMega Alakazam   Psychic     NaN    590   55      50
# 154  142  AerodactylMega Aerodactyl      Rock  Flying    615   80     135
# 19    15      BeedrillMega Beedrill       Bug  Poison    495   65     150
# 109  101                  Electrode  Electric     NaN    480   60      50
# 164  150        MewtwoMega Mewtwo Y   Psychic     NaN    780  106     150
# ..   ...                        ...       ...     ...    ...  ...     ...
# 753  683                 Aromatisse     Fairy     NaN    462  101      72
# 748  679                    Honedge     Steel   Ghost    325   45      80
# 788  712                   Bergmite       Ice     NaN    304   55      69
# 789  713                    Avalugg       Ice     NaN    514   95     117
# 752  682                   Spritzee     Fairy     NaN    341   78      52
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
attack_mean = data["Attack"].mean()
def set_attack(val):
    if val < attack_mean:
        return "Attack Low"
    else:
        return "Attack High"

# %%
data.loc[:,["type"]].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-136059f4f714> in <module>
# ----> 1 data.loc[:,["type"]].value_counts()
#
# E:\New folder\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# E:\New folder\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ...

# %%
data["Attack_high_low"]= data["Attack"].apply(set_attack)
data

# %%
data=pd.read_csv("netflix_titles.csv")
data

# %%
data.loc[:,["type"]].value_counts()

# %%
type(data.loc[3,"cast"])

# %%
val = data["cast"]
val["cast"]=data.cast.astype(str)
type(val)

# %%
data

# %%
# val = data["cast"]
val["cast"]=data.cast.astype(str)
type(val)

# %%
data.loc[data["title"]!="Kota Factory"]

# %%
data.loc[data["title"]=="Kota Factory"]

# %%
data.loc[data["rating"]=="PG-13"]

# %%
data["cast"].isnull().sum()

# %%
# data["cast"]=data["cast"].replace(np.nan,"faisal")
# data.loc[data["cast"]=="faisal"]

# %%
data.groupby("director")["release_year"].value_counts()

# %%
def cast_len(val):
    if val =="None":
        return 0
    else:
        return len(str(val).split(", "))

# %%
data["cast"].isnull().sum()

# %%
data["cast"].replace(np.nan,"None",inplace=True)
data

# %%
data["Cast_len"]=data["cast"].apply[cast_len]

# %%
data.head()
